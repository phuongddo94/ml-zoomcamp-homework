# %% [markdown]
# ## 8.1 Import TF and Keras, loading image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
path = r'./clothing-dataset-small/train/t-shirt'
name = 'd9cf9703-1375-4381-a625-d4ea016cc47c.jpg'
img_path = f'{path}/{name}'
load_img (img_path, target_size=(299, 299))
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
img = load_img (img_path, target_size=(299, 299))

# %%
x = np.array(img)
x.shape
# Out:
# (299, 299, 3)

# %% [markdown]
# ## 8.2 Pre-trained CNN
#
# - Imagenet dataset: https://www.image-net.org/
# - Pre-trained models: https://keras.io/api/applications/

# %% [markdown]
# - Keras is a high level abstraction layer on top of tensorflow
# - The `keras.application` module has different pre-trained models with different architectures. We'll use the model Xception which takes the input image size of (299, 299) and each iamge's pixel is scaled between `-1` and `1`.
# - We create the instance of the pre-trained model using `model = Xception(weights='imagenet', input_shape=(299, 299, 3))`. Our model will use the weights from pre-trained imagenet and execpt the input shape of (299, 299, 3) for images.
# - Along with image size, the model also expects the batch_size which is the size of the batches of data. If one image is passed to the model, the then expected sha

# %%
from tensorflow.keras.applications.xception import Xception, preprocess_input, decode_predictions

# %%
model = Xception(weights='imagenet', input_shape=(299, 299, 3))
# Out:
# ...
# 91884032/91884032 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
X = np.array([x])

# %%
X.shape
# Out:
# (1, 299, 299, 3)

# %%
X = preprocess_input(X)

# %%
pred = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step

# %%
decode_predictions(pred)
# Out:
# [[('n03595614', 'jersey', 0.9069072),
#   ('n04370456', 'sweatshirt', 0.011993994),
#   ('n04525038', 'velvet', 0.0070570246),
#   ('n03598930', 'jigsaw_puzzle', 0.0029295608),
#   ('n04599235', 'wool', 0.002823608)]]
